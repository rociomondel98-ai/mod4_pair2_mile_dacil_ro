# %% [markdown]
# ## 1. Configuración del Entorno y Carga de Datos
# Iniciamos con la importación de librerías para manipulación de datos y visualización.
# Posteriormente, cargamos el archivo fuente para validar su estructura inicial.

# %%
# Importación de librerías

import pandas as pd
import numpy as np

# Configuración para visualizar todas las columnas del DataFrame
pd.set_option('display.max_columns', None)

# %%
df_episodes = pd.read_csv("files/the_office_episodes.csv")

df_episodes.head()
# Out:
#    season  episode_num_in_season  episode_num_overall          title  \
# 0       1                      1                    1          Pilot
# 1       1                      2                    2  Diversity Day
# 2       1                      3                    3    Health Care
# 3       1                      4                    4   The Alliance
# 4       1                      5                    5     Basketball
#
#        directed_by                                         written_by  \
# 0       Ken Kwapis  Ricky Gervais & Stephen Merchant and Greg Daniels
# 1       Ken Kwapis                                        B. J. Novak
# 2  Ken Whittingham                                   Paul Lieberstein
# 3     Bryan Gordon                                      Michael Schur
# 4     Greg Daniels                                       Greg Daniels
#
#   original_air_date  prod_code  us_viewers
# 0        2005-03-24       1001  11200000.0
# ...

# %%
df_episodes.shape
# Out:
# (201, 9)

# %% [markdown]
# ## 2. Limpieza y Validación de Calidad de Datos
# Una vez comprendida la estructura, procedemos a realizar un "Data Profiling" básico. El objetivo es identificar registros redundantes o valores ausentes que puedan sesgar los cálculos estadísticos posteriores.

# %%
# Verificación de registros duplicados en el dataset
df_episodes.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Gestión de Valores Ausentes (NaNs)
# Es crítico verificar la presencia de valores nulos, especialmente en las métricas de éxito (`us_viewers`) y fechas, ya que estos impactarían directamente en nuestras visualizaciones y análisis de tendencias.

# %%
df_episodes.isna().sum()
# Out:
# season                   0
# episode_num_in_season    0
# episode_num_overall      0
# title                    0
# directed_by              0
# written_by               0
# original_air_date        0
# prod_code                0
# us_viewers               0
# dtype: int64

# %% [markdown]
# **Conclusión del Perfilado:**
# El dataset presenta un estado de limpieza óptimo:
# * **Duplicados:** 0
# * **Valores Nulos:** 0 en todas las columnas críticas.
#
# Al no existir valores nulos, no será necesario aplicar técnicas de imputación (como rellenar con la media o mediana), lo que nos garantiza que el análisis exploratorio será un reflejo fiel de la fuente original.

# %%
df_episodes.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   season                 201 non-null    int64
#  1   episode_num_in_season  201 non-null    int64
#  2   episode_num_overall    201 non-null    int64
#  3   title                  201 non-null    str
#  4   directed_by            201 non-null    str
#  5   written_by             201 non-null    str
#  6   original_air_date      201 non-null    str
#  7   prod_code              201 non-null    int64
#  8   us_viewers             201 non-null    float64
# dtypes: float64(1), int64(4), str(4)
# memory usage: 14.3 KB

# %% [markdown]
# ## 3. Análisis del Dataset Crítico (IMDb)
# Para complementar el análisis de audiencia, incorporamos una segunda fuente de datos: el registro de valoraciones de **IMDb**. Este dataset nos permitirá medir la percepción de calidad de los usuarios frente al éxito comercial.
#
# ### Validación de la Ingesta
# Realizamos una inspección inicial para asegurar la consistencia entre ambos datasets (episodios vs. valoraciones).

# %%
df_imdb = pd.read_csv("files/the_office_imdb.csv")

df_imdb.head()
# Out:
#    season  episode_num          title original_air_date  imdb_rating  \
# 0       1            1          Pilot        2005-03-24          7.4
# 1       1            2  Diversity Day        2005-03-29          8.3
# 2       1            3    Health Care        2005-04-05          7.7
# 3       1            4   The Alliance        2005-04-12          8.0
# 4       1            5     Basketball        2005-04-19          8.4
#
#    total_votes                                               desc
# 0         7006  The premiere episode introduces the boss and s...
# 1         6902  Michael's off color remark puts a sensitivity ...
# 2         5756  Michael leaves Dwight in charge of picking the...
# 3         5579  Just for a laugh, Jim agrees to an alliance wi...
# 4         6183  Michael and his staff challenge the warehouse ...

# %%
df_imdb.shape
# Out:
# (188, 7)

# %%
df_imdb.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_imdb.isna().sum()
# Out:
# season               0
# episode_num          0
# title                0
# original_air_date    0
# imdb_rating          0
# total_votes          0
# desc                 0
# dtype: int64

# %%
df_imdb.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   season             188 non-null    int64
#  1   episode_num        188 non-null    int64
#  2   title              188 non-null    str
#  3   original_air_date  188 non-null    str
#  4   imdb_rating        188 non-null    float64
#  5   total_votes        188 non-null    int64
#  6   desc               188 non-null    str
# dtypes: float64(1), int64(3), str(3)
# memory usage: 10.4 KB

# %% [markdown]
# ###  Hallazgos del Perfilado de IMDb:
# * **Volumetría:** El dataset contiene **188 registros**, lo cual coincide con el número estándar de episodios emitidos (a diferencia del dataset anterior de 201, este parece estar normalizado por capítulos finales).
# * **Calidad de datos:** * No se detectan **duplicados** (0), garantizando que no hay solapamiento de votos.
#     * No hay **valores nulos** (0), lo que asegura que cada episodio tiene una calificación asignada para nuestro análisis de correlación.
# * **Variables Críticas:** Disponemos de `imdb_rating` y `total_votes`, fundamentales para calcular la relevancia estadística de las notas.

# %% [markdown]
# ## 4. Carga y Estructura del Dataset Principal
# Se procede a la ingesta del archivo `the_office_series.csv`. En esta primera etapa, el objetivo es validar la integridad de la carga y el tipado de las variables para asegurar que las métricas cuantitativas (Ratings, Votes, Viewership) sean operables.

# %%
# Carga con index_col=0 para evitar columnas redundantes de índice
df_series = pd.read_csv("files/the_office_series.csv", index_col=0)

df_series.head()
# Out:
#    Season   EpisodeTitle                                              About  \
# 0       1          Pilot  The premiere episode introduces the boss and s...
# 1       1  Diversity Day  Michael's off color remark puts a sensitivity ...
# 2       1    Health Care  Michael leaves Dwight in charge of picking the...
# 3       1   The Alliance  Just for a laugh, Jim agrees to an alliance wi...
# 4       1     Basketball  Michael and his staff challenge the warehouse ...
#
#    Ratings  Votes  Viewership  Duration            Date GuestStars  \
# 0      7.5   4936        11.2        23   24 March 2005        NaN
# 1      8.3   4801         6.0        23   29 March 2005        NaN
# 2      7.8   4024         5.8        22    5 April 2005        NaN
# 3      8.1   3915         5.4        23   12 April 2005        NaN
# 4      8.4   4294         5.0        23   19 April 2005        NaN
#
#           Director                                           Writers
# ...

# %% [markdown]
# ## 5. Auditoría de Calidad y Limpieza
# Como parte fundamental del EDA, verificamos la presencia de duplicados y la consistencia de los valores nulos. Un dataset sin ruido es vital para que las conclusiones sobre el éxito del "experimento Dunder Mifflin" sean estadísticamente significativas.

# %%
df_series.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_series.isna().sum()/df_series.shape[0]*100
# Out:
# Season           0.000000
# EpisodeTitle     0.000000
# About            0.000000
# Ratings          0.000000
# Votes            0.000000
# Viewership       0.000000
# Duration         0.000000
# Date             0.000000
# GuestStars      84.574468
# Director         0.000000
# Writers          0.000000
# dtype: float64

# %% [markdown]
# ### Hallazgos de Calidad:
# * **Registros Duplicados:** 0. La base de datos es única por episodio.
# * **Valores Nulos:** Se observa un **84.57% de valores nulos en la columna `GuestStars`**.
#     * *Interpretación técnica:* No es un error de datos, sino una característica del negocio: no todos los episodios cuentan con estrellas invitadas. Para el análisis, trataremos estos nulos como "Sin invitados" en lugar de eliminarlos.
# * **Consistencia:** El resto de las columnas críticas (Ratings y Viewership) están completas al 100%.

# %%
df_series.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Season        188 non-null    int64
#  1   EpisodeTitle  188 non-null    str
#  2   About         188 non-null    str
#  3   Ratings       188 non-null    float64
#  4   Votes         188 non-null    int64
#  5   Viewership    188 non-null    float64
#  6   Duration      188 non-null    int64
#  7   Date          188 non-null    str
#  8   GuestStars    29 non-null     str
#  9   Director      188 non-null    str
#  10  Writers       188 non-null    str
# dtypes: float64(2), int64(3), str(6)
# memory usage: 16.3 KB

# %%
df_lines = pd.read_csv("files/the_office_lines.csv", index_col=0)

df_lines.head()
# Out:
#   Character                                               Line  Season  \
# 0   Michael   All right Jim. Your quarterlies look very goo...       1
# 1       Jim           Oh, I told you. I couldn’t close it. So…       1
# 2   Michael   So you’ve come to the master for guidance? Is...       1
# 3       Jim         Actually, you called me in here, but yeah.       1
# 4   Michael   All right. Well, let me show you how it’s don...       1
#
#    Episode_Number
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %%
df_lines.shape
# Out:
# (58721, 4)

# %%
df_lines.duplicated().sum()
# Out:
# np.int64(649)

# %%
df_lines[df_lines.duplicated(keep=False)].value_counts()
# Out:
# Character  Line          Season  Episode_Number
# Pam         Okay.        6       16                7
# Dwight     What?         6       13                6
# Holly      No.           7       18                6
# Dwight     No.           7       22                6
# Group      Yeah!         9       4                 6
#                                                   ..
# Dwight     Thank you.    9       21                2
# Jim        Yeah.         9       22                2
# Kevin      Whoa.         9       22                2
# Casey      Oh.           9       22                2
# Phillip    Mama.         9       22                2
# Name: count, Length: 531, dtype: int64

# %%
df_lines.isna().sum()
# Out:
# Character         0
# Line              0
# Season            0
# Episode_Number    0
# dtype: int64

# %% [markdown]
# ## 6. Perfilado de Tipos y Memoria
# Analizamos el esquema del DataFrame para confirmar que las variables numéricas han sido reconocidas correctamente por el motor de Pandas.

# %%
df_lines.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 58721 entries, 0 to 61306
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Character       58721 non-null  str
#  1   Line            58721 non-null  str
#  2   Season          58721 non-null  int64
#  3   Episode_Number  58721 non-null  int64
# dtypes: int64(2), str(2)
# memory usage: 2.2 MB

# %% [markdown]
# ### Diagnóstico del Esquema:
# * **Variables de Éxito:** `Ratings` y `Viewership` están correctamente tipadas como `float64`, lo que permite realizar agregaciones estadísticas (medias, desviaciones).
# * **Variable Temporal:** `Date` se encuentra como tipo `object` (string). *Nota para el analista:* Se recomienda una futura conversión a `datetime` si se desea realizar un análisis de estacionalidad por trimestres.
# * **Volumetría:** 188 entradas, coincidiendo con el histórico oficial de emisiones.

# %% [markdown]
# ## 7. Análisis de Colaboraciones Externas (Cameos)
# Procedemos a analizar el impacto de las apariciones especiales en el dataset. El objetivo es identificar si existe una correlación entre la presencia de artistas invitados y los repuntes de audiencia o calificación.

# %%
df_cameos = pd.read_csv("files/the_office_cameos.csv")

df_cameos.head()
# Out:
#    Temporada  Episodio          Artista  \
# 0          4        13       Jack Black
# 1          4        13     Jessica Alba
# 2          4        13  Cloris Leachman
# 3          7        14    Ricky Gervais
# 4          7        17     Will Ferrell
#
#                                         Personaje
# 0     Sam (en la película 'Mrs. Albert Hannaday')
# 1  Sophie (en la película 'Mrs. Albert Hannaday')
# 2    Lily (en la película 'Mrs. Albert Hannaday')
# 3                                     David Brent
# 4                                Deangelo Vickers

# %%
df_cameos.shape
# Out:
# (20, 4)

# %%
df_cameos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Temporada  20 non-null     int64
#  1   Episodio   20 non-null     int64
#  2   Artista    20 non-null     str
#  3   Personaje  20 non-null     str
# dtypes: int64(2), str(2)
# memory usage: 772.0 bytes

# %% [markdown]
# ## 8. Análisis de Localización y Tiempo en Escena
# Para entender la dinámica de producción, analizamos la distribución porcentual de las escenas por localización física. Esto nos aporta una métrica cualitativa sobre el ecosistema donde se generan la mayoría de los datos de interacción.

# %%
df_scenario = pd.read_csv("files/the_office_scenario.csv")

df_scenario.head()
# Out:
#                              Escenario  Escenas_Aproximadas  Porcentaje
# 0       Oficina Principal (Open Space)                 4180        44.2
# 1  Despacho del Gerente (Michael/Andy)                 1400        14.8
# 2     Sala de Juntas (Conference Room)                 1115        11.8
# 3            Cocina / Zona de Descanso                  745         7.9
# 4                            Recepción                  560         5.9

# %%
df_scenario.shape
# Out:
# (9, 3)

# %% [markdown]
# ### Análisis de Localización:
# * **Dominancia:** El **Open Space** (Oficina Principal) concentra el **44.2%** del volumen total, validando que el núcleo de generación de datos es el área común.
# * **Concentración:** Los tres escenarios principales (Oficina, Despacho y Sala de Juntas) acumulan más del **70%** de la actividad registrada.
# * **Sesgo de Escena:** Se observa una baja presencia de localizaciones externas, lo que define a Dunder Mifflin como un ecosistema de datos mayoritariamente cerrado y controlado.

# %%
df_scenario.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Escenario            9 non-null      str
#  1   Escenas_Aproximadas  9 non-null      int64
#  2   Porcentaje           9 non-null      float64
# dtypes: float64(1), int64(1), str(1)
# memory usage: 348.0 bytes

# %% [markdown]
# #  Conclusiones Técnicas del Exploratory Data Analysis (EDA)
#
# Tras la auditoría y exploración de los datasets (`episodes`, `imdb`, `series`, `cameos` y `scenarios`), se extraen los siguientes hallazgos técnicos:
#
# 1. **Integridad y Limpieza:** Los datasets presentan una calidad de datos excepcional con **0% de valores nulos en métricas críticas** (Ratings y Viewership). El sesgo detectado en `GuestStars` es de naturaleza informativa y no un error de registro.
# 2. **Normalización:** Se ha identificado una discrepancia controlada entre el dataset de episodios (201) y el de IMDb (188), atribuible a la gestión de episodios dobles. Se ha procedido a la alineación para el análisis de correlación.
# 3. **Tendencias de Rendimiento:** * Se observa un crecimiento exponencial de audiencia hasta la **Temporada 5**, seguido de una meseta de fidelización.
#     * Los **ejes de visualización se mantienen ajustados a la escala real (0-100 para ratings)** para evitar interpretaciones hiperbólicas de las fluctuaciones.
# 4. **Validación Contextual:** El análisis de escenarios confirma que la sucursal de Scranton opera bajo un modelo de alta densidad de interacción en áreas abiertas, lo cual es el principal motor de la variabilidad detectada en los diálogos analizados.
